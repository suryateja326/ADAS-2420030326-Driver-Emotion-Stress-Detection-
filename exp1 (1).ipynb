# %%
import cv2
import numpy as np
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions

model = MobileNetV2(weights='imagenet')
image = cv2.imread("WIN_20250814_10_28_09_Pro.jpg")
img = cv2.resize(image, (224,224))
x = np.expand_dims(img, axis=0)
x = preprocess_input(x)
predictions = model.predict(x)
print(decode_predictions(predictions, top=3)[0])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
brightness = np.mean(gray)
print("Ambient Brightness:",brightness)
if brightness < 80:
    print("Headlights ON")
else:
    print("Headlights OFF")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# [('n03424325', 'gasmask', np.float32(0.32647312)), ('n03868863', 'oxygen_mask', np.float32(0.12681466)), ('n04229816', 'ski_mask', np.float32(0.06870821))]
# Ambient Brightness: 139.52333116319446
# Headlights OFF
